# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy.optimize import curve_fit

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler

import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

# %%
N = 100

folder_path = r"S:/Nit Durgapur/College 6th Sem/CSIR-CMERI/Friction_Modelling/EXP_1/EXP_1_Data/12_06_2026"

joint_files = {
    1: "Joint_1_Clean.csv",
    2: "Joint_2_Clean.csv",
    3: "Joint_3_Clean.csv",
    5: "Joint_5_Clean.csv"
}

# %% [markdown]
# # HERE MODEL IS LEARNING THE TIME-SERIES DATA SINCE IT IS IN A CYCLE

# %% [markdown]
# # INFLATED R2 SCORE DUE TO HYSTERESIS

# %%
for joint, filename in joint_files.items():
    print("\n" + "=" * 80)
    print(f"JOINT {joint}")
    print("=" * 80)
    file_path = os.path.join(folder_path, filename)
    df = pd.read_csv(file_path)

    # =====================================================
    # COLUMNS
    # =====================================================
    mt_col = f"m_t_{joint}"
    tj_col = f"jts{joint}"
    v_col  = f"v{joint}"
    q_col  = f"q{joint}"

    # =====================================================
    # TIME VECTOR (200 Hz LOGGING)
    # =====================================================
    dt = 0.005
    time = np.arange(len(df)) * dt

    # =====================================================
    # DATA
    # =====================================================
    q = np.deg2rad(df[q_col].values)
    v = np.deg2rad(df[v_col].values)
    tm = df[mt_col].values
    tj = df[tj_col].values
    
    # Updated Equation: Tf = NTm - (-Tj)
    Tf = N * tm - (-tj)
    
    X = np.column_stack([q, v])
    y = Tf

    # =====================================================
    # TRAIN TEST SPLIT
    # =====================================================
    n = len(X)
    train_end = int(0.70 * n)
    val_end = int(0.85 * n)
    
    X_train = X[ : train_end]
    X_val = X[train_end : val_end]
    X_test = X[val_end : ]
    
    y_train = y[ : train_end]
    y_val = y[train_end : val_end]
    y_test = y[val_end : ]

    # =====================================================
    # SCALING
    # =====================================================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    X_test = scaler.transform(X_test)

    # =====================================================
    # MODEL
    # =====================================================
    model = Sequential([
        Dense(64, activation='tanh', input_shape=(2, )),
        Dense(64, activation='tanh'),
        Dense(32, activation='tanh'),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse')

    # =====================================================
    # TRAINING
    # =====================================================
    early_stop = EarlyStopping(patience=20, restore_best_weights=True)
    history = model.fit(
        X_train,
        y_train,
        validation_data=(
            X_val,
            y_val
        ),
        epochs=500,
        batch_size=512,
        callbacks=[early_stop],
        verbose=1
    )

    # =====================================================
    # TRAINING HISTORY
    # =====================================================
    plt.figure(figsize=(10,5))
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.xlabel('Epoch')
    plt.ylabel('MSE')
    plt.title(f'Joint {joint} Training History')
    plt.legend()
    plt.grid(True)
    plt.show()

    # =====================================================
    # PREDICTION
    # =====================================================
    y_pred = model.predict(X_test, verbose=0).flatten()

    # =====================================================
    # METRICS
    # =====================================================
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    print(f"\nJoint {joint}")
    print(f"RMSE = {rmse:.4f}")
    print(f"MAE = {mae:.4f}")
    print(f"R² = {r2:.4f}")

    # =====================================================
    # EXTRACT UNSCALED VELOCITY FOR PLOTTING
    # =====================================================
    v_test_unscaled = scaler.inverse_transform(X_test)[ :, 1]
    residual = y_test - y_pred

    # =====================================================
    # SCATTER: ACTUAL VS PREDICTED
    # =====================================================
    plt.figure(figsize=(7,7))
    plt.scatter(y_test, y_pred, alpha=0.4, s=5)
    mn = min(y_test.min(), y_pred.min())
    mx = max(y_test.max(), y_pred.max())
    plt.plot([mn, mx], [mn, mx], 'r')
    plt.xlabel("Actual Friction Torque")
    plt.ylabel("Predicted Friction Torque")
    plt.title(f"Joint {joint} Actual vs Predicted")
    plt.grid(True)
    plt.show()

    # =====================================================
    # RESIDUAL VS VELOCITY
    # =====================================================
    plt.figure(figsize=(10,5))
    plt.scatter(v_test_unscaled, residual, s=5, alpha=0.5)
    plt.axhline(0, color='r', linestyle='--')
    plt.xlabel("Velocity (rad/s)")
    plt.ylabel("Residual")
    plt.title(f"Joint {joint} Residual vs Velocity")
    plt.grid(True)
    plt.show()

    # =====================================================
    # ACTUAL VS PREDICTED FRICTION TORQUE AGAINST VELOCITY
    # =====================================================
    plt.figure(figsize=(10,6))
    
    # Actual data as blue dots
    plt.scatter(v_test_unscaled, y_test, s=5, alpha=0.3, label='Actual')
    
    # Predicted data as red dots (Changed from plt.plot to plt.scatter)
    plt.scatter(v_test_unscaled, y_pred, color='red', s=5, alpha=0.5, label='Predicted')
    
    plt.xlabel("Velocity (rad/s)")
    plt.ylabel("Friction Torque: Tf = NTm - (-Tj)")
    plt.title(f"Joint {joint} Friction Curve")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# ...
# JOINT 1
# ...
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Epoch 1/500
# c:\Users\HP\.conda\envs\csirinternshipenv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 201.5507 - val_loss: 127.3463
# Epoch 2/500
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 88.2354 - val_loss: 83.6634
# Epoch 3/500
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 56.5676 - val_loss: 57.3525
# Epoch 4/500
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 37.1522 - val_loss: 40.2495
# Epoch 5/500
# ...

# %% [markdown]
# # TRAINING THE MODEL WITH UNIQUE DATASET AND BY TTS

# %% [markdown]
# # INFLATED R2 SCORE DUE TO HYSTERESIS

# %%
N = 100

folder_path = r"S:/Nit Durgapur/College 6th Sem/CSIR-CMERI/Friction_Modelling/EXP_1/EXP_1_Data/12_06_2026"

joint_files = {
    1: "1_Unique.csv",
    2: "2_Unique.csv",
    3: "3_Unique.csv",
    5: "5_Unique.csv"
}

# %%
for joint, filename in joint_files.items():
    print("\n" + "=" * 80)
    print(f"JOINT {joint}")
    print("=" * 80)
    file_path = os.path.join(folder_path, filename)        
    df = pd.read_csv(file_path)

    # =====================================================
    # COLUMNS
    # =====================================================
    mt_col = f"m_t_{joint}"
    tj_col = f"jts{joint}"
    v_col  = f"v{joint}"
    q_col  = f"q{joint}"

    # =====================================================
    # TIME VECTOR (200 Hz LOGGING)
    # =====================================================
    dt = 0.005
    time = np.arange(len(df)) * dt

    # =====================================================
    # DATA
    # =====================================================
    q = np.deg2rad(df[q_col].values)
    v = np.deg2rad(df[v_col].values)
    tm = df[mt_col].values
    tj = df[tj_col].values
    
    # Updated Equation: Tf = NTm - (-Tj)
    Tf = N * tm - (-tj)

    X = np.column_stack([q, v])
    y = Tf

    # =====================================================
    # RAW TIME SERIES
    # =====================================================
    fig, ax = plt.subplots(4, 1, figsize=(16,10), sharex=True)
    ax[0].plot(time, tm)
    ax[0].set_ylabel("Motor Torque")
    ax[0].set_title(f"Joint {joint} Raw Data")
    ax[1].plot(time, tj)
    ax[1].set_ylabel("Joint Torque")
    ax[2].plot(time, v)
    ax[2].set_ylabel("Velocity")
    ax[3].plot(time, q)
    ax[3].set_ylabel("Position")
    ax[3].set_xlabel("Time (s)")
    plt.tight_layout()
    plt.show()

    # =====================================================
    # RANDOM SPLIT: 70% Train, 10% Val, 20% Test
    # =====================================================
    # 1. First split out the 20% for testing
    X_temp, X_test, y_temp, y_test, time_temp, time_test = train_test_split(X, y, time, test_size=0.20, random_state=42)
    # 2. Split the remaining 80% to get 70% Train / 10% Val
    # 10/80 = 0.125 (So we use 12.5% of the temp set for validation)
    X_train, X_val, y_train, y_val, time_train, time_val = train_test_split(X_temp, y_temp, time_temp, test_size=0.125, random_state=42)
    # 3. Re-sort the Test set by time so the line plots below don't look like scribbles
    sort_idx = np.argsort(time_test)
    time_test = time_test[sort_idx]
    X_test = X_test[sort_idx]
    y_test = y_test[sort_idx]
    print(f"\nTotal Samples : {len(X)}")
    print(f"Train Samples (70%): {len(X_train)}")
    print(f"Val Samples (10%): {len(X_val)}")
    print(f"Test Samples (20%): {len(X_test)}")

    # =====================================================
    # SCALING
    # =====================================================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    X_test = scaler.transform(X_test)

    # =====================================================
    # MODEL
    # =====================================================
    model = Sequential([
        Dense(64, activation='tanh', input_shape=(2, )),
        Dense(64, activation='tanh'),
        Dense(32, activation='tanh'),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse')

    # =====================================================
    # TRAINING
    # =====================================================
    early_stop = EarlyStopping(patience=20, restore_best_weights=True)
    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        epochs=500,
        batch_size=512,
        callbacks=[early_stop],
        verbose=1
    )

    # =====================================================
    # TRAINING HISTORY
    # =====================================================
    plt.figure(figsize=(10,5))
    plt.plot(history.history['loss'], label='Train')
    plt.plot(history.history['val_loss'], label='Validation')
    plt.xlabel('Epoch')
    plt.ylabel('MSE')
    plt.title(f'Joint {joint} Training History')
    plt.legend()
    plt.grid(True)
    plt.show()

    # =====================================================
    # PREDICTION
    # =====================================================
    y_pred = model.predict(X_test, verbose=0).flatten()

    # =====================================================
    # METRICS
    # =====================================================
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print(f"\nJoint {joint} Model Evaluation")
    print(f"RMSE = {rmse:.4f}")
    print(f"MAE = {mae:.4f}")
    print(f"R² = {r2:.4f}")

    # =====================================================
    # ACTUAL VS PREDICTED (TIME DOMAIN - ON TEST SET)
    # =====================================================
    plt.figure(figsize=(15,5))
    plt.plot(time_test, y_test, label="Actual (Test Set)", alpha=0.8)
    plt.plot(time_test, y_pred, label="Predicted", alpha=0.8)
    plt.xlabel("Time (s)")
    plt.ylabel("Friction Torque")
    plt.title(f"Joint {joint} Actual vs Predicted (Random 20% Test Set)")
    plt.legend()
    plt.grid(True)
    plt.show()

    # =====================================================
    # SCATTER (ACTUAL VS PREDICTED)
    # =====================================================
    plt.figure(figsize=(7,7))
    plt.scatter(y_test, y_pred, alpha=0.4)
    mn = min(y_test.min(), y_pred.min())
    mx = max(y_test.max(), y_pred.max())
    plt.plot([mn, mx], [mn, mx], 'r')
    plt.xlabel("Actual Friction Torque")
    plt.ylabel("Predicted Friction Torque")
    plt.title(f"Joint {joint} Actual vs Predicted Scatter")
    plt.grid(True)
    plt.show()

    # =====================================================
    # RESIDUAL OVER TIME
    # =====================================================
    residual = y_test - y_pred
    plt.figure(figsize=(15,5))
    plt.plot(time_test, residual)
    plt.axhline(0, color='r', linestyle='--')
    plt.xlabel("Time (s)")
    plt.ylabel("Residual")
    plt.title(f"Joint {joint} Residual (Test Set)")
    plt.grid(True)
    plt.show()

    # =====================================================
    # RESIDUAL HISTOGRAM
    # =====================================================
    plt.figure(figsize=(8,5))
    plt.hist(residual, bins=50)
    plt.xlabel("Residual")
    plt.ylabel("Count")
    plt.title(f"Joint {joint} Residual Distribution")
    plt.grid(True)
    plt.show()

    # =====================================================
    # COMPLETE FRICTION CURVE
    # =====================================================
    v_test = scaler.inverse_transform(X_test)[:, 1]
    plt.figure(figsize=(10,6))
    plt.scatter(v, y, s=5, alpha=0.2, label='Actual Full Data')
    plt.scatter(v_test, y_pred, s=8, color='red', label='Predicted (20% Test Set)')
    plt.xlabel("Velocity (rad/s)")
    plt.ylabel("Friction Torque: Tf = NTm - (-Tj)")
    plt.title(f"Joint {joint} Complete Friction Curve")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# ...
# JOINT 1
# ...
# Total Samples : 7709
# Train Samples (70%): 5396
# Val Samples (10%): 771
# Test Samples (20%): 1542
# Epoch 1/500
# c:\Users\HP\.conda\envs\csirinternshipenv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 327.1232 - val_loss: 284.1425
# Epoch 2/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 251.4980 - val_loss: 212.1659
# Epoch 3/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 187.5339 - val_loss: 160.5598
# Epoch 4/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 146.6270 - val_loss: 131.4579
# Epoch 5/500
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 123.7086 - val_loss: 114.4847
# Epoch 6/500
# ...

# %% [markdown]
# # TRAINING ON 30, 36, 42 AND TESTING ON 33, 39, 45 VELOCITIES

# %%
joint_files = {
    1: "1_Unique.csv",
    2: "2_Unique.csv",
    3: "3_Unique.csv",
    5: "5_Unique.csv"
}

N = 100

# %% [markdown]
# # SOMEWHAT CORRECT PREDICTION

# %%
for joint, filename in joint_files.items():
    print("\n" + "=" * 80)
    print(f"JOINT {joint}")
    print("=" * 80)
    
    file_path = os.path.join(folder_path, filename)        
    
    try:
        df = pd.read_csv(file_path)
    except FileNotFoundError:
        print(f"File not found: {file_path}. Skipping...")
        continue

    # =====================================================
    # COLUMNS & DATA PREP
    # =====================================================
    mt_col = f"m_t_{joint}"
    tj_col = f"jts{joint}"
    v_col  = f"v{joint}"
    q_col  = f"q{joint}"

    dt = 0.005
    time = np.arange(len(df)) * dt

    q = np.deg2rad(df[q_col].values)
    v_raw_deg = df[v_col].values 
    v = np.deg2rad(v_raw_deg)
    tm = df[mt_col].values
    tj = df[tj_col].values
    
    # Updated Equation: Tf = NTm - (-Tj)
    Tf = N * tm - (-tj)
    
    X = np.column_stack([q, v])
    y = Tf

    # =====================================================
    # RAW FRICTION CURVE (VELOCITY PLOT)
    # =====================================================
    plt.figure(figsize=(10,6))
    plt.scatter(v, y, s=5, alpha=0.3, color='dodgerblue')
    plt.xlabel("Velocity (rad/s)")
    plt.ylabel("Friction Torque: Tf = NTm - (-Tj)")
    plt.title(f"Joint {joint} Raw Friction Curve (Velocity vs Torque)")
    plt.grid(True)
    plt.show()

    # =====================================================
    # DYNAMIC CYCLE SPLITTING (ADAPTED PER JOINT)
    # =====================================================
    zero_crossings = np.where(np.diff(np.sign(v_raw_deg)))[0]
    cycle_starts = np.insert(zero_crossings, 0, 0)
    cycle_ends = np.append(zero_crossings, len(v_raw_deg)-1)
    
    cycle_list = []
    # Identify all valid cycles and their peak speeds
    for start, end in zip(cycle_starts, cycle_ends):
        if start >= end: continue
        cycle_v = v_raw_deg[start:end]
        if len(cycle_v) == 0: continue
        peak_v = np.max(np.abs(cycle_v))
        if peak_v < 5.0: continue # Skip noise/zero movement
        cycle_list.append((start, end, peak_v))
        
    train_indices, test_indices = [], []
    title_train, title_test = "", ""
    
    if joint == 2:
        # Joint 2 only has 30 rad/s cycles. Train on first 75%, test on last 25%.
        split_idx = int(len(cycle_list) * 0.75)
        for i, (s, e, p) in enumerate(cycle_list):
            if i < split_idx:
                train_indices.extend(range(s, e))
            else:
                test_indices.extend(range(s, e))
        title_train = "Train (First 75% of 30 rad/s cycles)"
        title_test = "Test (Last 25% of 30 rad/s cycles)"
        
    elif joint == 3:
        # Joint 3 Interpolation test: Train on high speeds (~42 rad/s), Predict on lower speeds (~32 rad/s)
        for s, e, p in cycle_list:
            if abs(p - 42) <= 3.0: 
                train_indices.extend(range(s, e))
            elif abs(p - 32) <= 3.0: 
                test_indices.extend(range(s, e))
        title_train = "Train (Cycles ~40-42 rad/s)"
        title_test = "Test (Cycles ~30-32 rad/s)"
        
    else:
        # Joints 1 and 5 have the full sweeps
        train_targets, test_targets = [30, 36, 42], [33, 39, 45]
        for s, e, p in cycle_list:
            if any(abs(p - t) <= 2.5 for t in train_targets):
                train_indices.extend(range(s, e))
            elif any(abs(p - t) <= 2.5 for t in test_targets):
                test_indices.extend(range(s, e))
        title_train = "Train (Cycles ~30, 36, 42)"
        title_test = "Test (Unseen ~33, 39, 45)"
            
    train_idx = np.array(train_indices)
    test_idx = np.array(test_indices)
    
    if len(train_idx) == 0 or len(test_idx) == 0:
        print(f"WARNING: Missing train/test split data for Joint {joint}.")
        continue
    
    X_temp, y_temp = X[train_idx], y[train_idx]
    X_test, y_test = X[test_idx], y[test_idx]
    
    val_split = int(0.9 * len(X_temp))
    shuffle_idx = np.random.permutation(len(X_temp))
    X_temp_shuffled, y_temp_shuffled = X_temp[shuffle_idx], y_temp[shuffle_idx]
    
    X_train, y_train = X_temp_shuffled[:val_split], y_temp_shuffled[:val_split]
    X_val, y_val = X_temp_shuffled[val_split:], y_temp_shuffled[val_split:]
    
    print(f"\nTotal Samples : {len(X)}")
    print(f"Train Samples : {len(X_train)} | {title_train}")
    print(f"Val Samples   : {len(X_val)} | (From Train Set)")
    print(f"Test Samples  : {len(X_test)} | {title_test}")

    # =====================================================
    # SCALING & MODEL
    # =====================================================
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_val = scaler.transform(X_val)
    X_test = scaler.transform(X_test)

    # Fixed layer definitions to prevent syntax error
    model = Sequential([
        Dense(64, activation='tanh', input_shape=(2, )),
        Dense(64, activation='tanh'),
        Dense(32, activation='tanh'),
        Dense(1)
    ])
    model.compile(optimizer='adam', loss='mse')

    # =====================================================
    # TRAINING
    # =====================================================
    early_stop = EarlyStopping(patience=20, restore_best_weights=True)
    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=1000, 
        batch_size=512,
        callbacks=[early_stop], 
        verbose=0
    )

    # =====================================================
    # METRICS
    # =====================================================
    y_pred = model.predict(X_test, verbose=0).flatten()
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    mae = mean_absolute_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print(f"\nJoint {joint} Model Evaluation")
    print(f"RMSE = {rmse:.4f}")
    print(f"MAE = {mae:.4f}")
    print(f"R² = {r2:.4f}")

    # =====================================================
    # COMPLETE FRICTION CURVE (VELOCITY PLOT)
    # =====================================================
    v_test_plot = scaler.inverse_transform(X_test)[:, 1]
    
    # Bug fix: X_temp was never scaled, so we don't need to inverse_transform it
    v_train_plot = X_temp[:, 1] 

    plt.figure(figsize=(12, 8))
    
    # Plot 1: The background training data
    plt.scatter(v_train_plot, y_temp, s=2, alpha=0.1, color='grey', label=title_train)
    
    # Plot 2: The actual unseen test data
    plt.scatter(v_test_plot, y_test, s=15, alpha=0.5, color='dodgerblue', label=f'Actual {title_test}')
    
    # Plot 3: The model's prediction for the test data
    plt.scatter(v_test_plot, y_pred, s=10, alpha=0.8, color='red', label=f'Predicted {title_test}')
    
    plt.xlabel("Velocity (rad/s)")
    plt.ylabel("Friction Torque: Tf = NTm - (-Tj)")
    plt.title(f"Joint {joint} Friction Curve: Actual vs Predicted")
    plt.legend()
    plt.grid(True)
    plt.show()

    # =====================================================
    # RESIDUAL SCATTER (PREDICTED VS ACTUAL)
    # =====================================================
    plt.figure(figsize=(7,7))
    plt.scatter(y_test, y_pred, alpha=0.4)
    mn = min(y_test.min(), y_pred.min())
    mx = max(y_test.max(), y_pred.max())
    plt.plot([mn, mx], [mn, mx], 'r')
    plt.xlabel("Actual Friction Torque")
    plt.ylabel("Predicted Friction Torque")
    plt.title(f"Joint {joint} Actual vs Predicted (Test Set)")
    plt.grid(True)
    plt.show()
# Out:
# ...
# JOINT 1
# ...
# Total Samples : 7709
# Train Samples : 4310 | Train (Cycles ~30, 36, 42)
# Val Samples   : 479 | (From Train Set)
# Test Samples  : 2850 | Test (Unseen ~33, 39, 45)
# c:\Users\HP\.conda\envs\csirinternshipenv\lib\site-packages\keras\src\layers\core\dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Joint 1 Model Evaluation
# RMSE = 1.2067
# MAE = 0.9603
# R² = 0.9961
# ...
# JOINT 2
# ...
# Total Samples : 672
# Train Samples : 429 | Train (First 75% of 30 rad/s cycles)
# Val Samples   : 48 | (From Train Set)
# Test Samples  : 181 | Test (Last 25% of 30 rad/s cycles)
# ...
